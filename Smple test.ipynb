# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install '/content/drive/MyDrive/bert/tool/am_complexity-1.0-py2.py3-none-any.whl'
# !pip install '/content/drive/MyDrive/bert/tool/am_complexity-1.0-py2.py3-none-any.whl'
# Out:
# Processing ./drive/MyDrive/bert/tool/am_complexity-1.0-py2.py3-none-any.whl
# ...
# Processing ./drive/MyDrive/bert/tool/am_complexity-1.0-py2.py3-none-any.whl
# am-complexity is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.

# %%
from am_complexity.Anotator_tool import amTextPreprocessing
texts=open("/content/drive/MyDrive/freetext.txt",'r',encoding="utf-8").read()
amTextPreprocessing(texts)

# %%
from am_complexity.Anotator_tool import ComplexityAnotator
texts=open("/content/drive/MyDrive/freetext.txt",'r',encoding="utf-8").read()
ComplexityAnotator(texts)
# Out:
# ቀረረ
# ካፖርቱን ተቀብላ በሬስቶራንቱ ውስጥ ወደ ቀረው ብቸኛ ጠረጴዛ እየመራች ወስዳ በክብር አስቀመጠችው
#
# 7 Sentencess are Annotated
# Please find the Dataset in path: /content/drive/MyDrive//dataset/dataset.xlsx
#
# data distribution: complex 85.7% Simple 14.3%
# Data imbalancation issue please add more data to balance the distribution
#
# Do You Want to Pre-process the dataset Y/Ng
# Preprocessing Data Please wait...
#
# Do You Want to Build vocab for pretrained models Y/Ng
# Building Vocab Please wait...

# %%
# from am_complexity.Anotator_tool import simplify
# sc=input("አረፍተነገሩን ያስገቡ")
# simplify(sc)
# Out:
# አረፍተነገሩን ያስገቡየግንቦትን ወበቅ ሽሽት ሕብረተሰቡ በየቤቱ መሽጎ ጎዳናው ላይ በርቀት ሰከም ሰከም ሲሉ ከማያቸው ሰዎች በቀር ማንም አይታይም ።
# Detected complex terms የግንቦትን ወበቅ ሽሽት ሕብረተሰቡ በየቤቱ መሽጎ ጎዳናው ላይ በርቀት ሰከም ሰከም ሲሉ ከማያቸው ሰዎች በቀር ማንም አይታይም ።
# Simple equivalents
#
# 1: የግንቦትን ሞቃት ሽሽት ሕብረተሰቡ በየቤቱ መሽጎ ጎዳናው ላይ በርቀት ሰከም ሰከም ሲሉ ከማያቸው ሰዎች በቀር ማንም አይታይም ።
# 2: የግንቦትን ጸሃይ ሽሽት ሕብረተሰቡ በየቤቱ መሽጎ ጎዳናው ላይ በርቀት ሰከም ሰከም ሲሉ ከማያቸው ሰዎች በቀር ማንም አይታይም ።
# 3: የግንቦትን ሀሩር ሽሽት ሕብረተሰቡ በየቤቱ መሽጎ ጎዳናው ላይ በርቀት ሰከም ሰከም ሲሉ ከማያቸው ሰዎች በቀር ማንም አይታይም ።
# 4: የግንቦትን የቀትሩ ሽሽት ሕብረተሰቡ በየቤቱ መሽጎ ጎዳናው ላይ በርቀት ሰከም ሰከም ሲሉ ከማያቸው ሰዎች በቀር ማንም አይታይም ።
# 5: የግንቦትን ሞቃታማ ሽሽት ሕብረተሰቡ በየቤቱ መሽጎ ጎዳናው ላይ በርቀት ሰከም ሰከም ሲሉ ከማያቸው ሰዎች በቀር ማንም አይታይም ።
